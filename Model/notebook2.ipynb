# %%
import numpy as np


def softmax(ligne):
    m = len(ligne)
    valeurs_exp = np.exp(ligne)
    sommeExp = np.sum(valeurs_exp) 
    return valeurs_exp / sommeExp
     


def jouet_attention(n,d) : 
    X = np.random.randn(n, d)
    S = X@X.T
    A=np.zeros((n,n))
    for i in range(n):
        A[i]=softmax(S[i])
    O=A@X

    # --- AFFICHAGE DES VÉRIFICATIONS ---
    print("=== VÉRIFICATION DES TAILLES ===")
    print(f"Taille de X  : {X.shape}")
    print(f"Taille de S : {S.shape}")
    print(f"Taille de A   : {A.shape}")
    print(f"Taille de O   : {O.shape}")
    
    print("\n=== CONTENU DE LA MATRICE A (Ligne 3) ===")
    # On affiche la ligne 3 pour voir les poids d'attention
    print(A[3])
    print(f"Somme de la ligne 3 : {np.sum(A[3])}")
    
    print("\n=== COMPARAISON X vs O (Ligne 0) ===")
    print(f"Vecteur original X[0] du mot {phrase[0]} :\n{X[0]}")
    print(f"Vecteur mis à jour O[0] du mot {phrase[0]}:\n{O[0]}")
    
    return X, S, A, O
phrase=["they","say","an","apple","a","day","keeps","the","doctor","away"]
X, S, A, O = jouet_attention(10, 8)
# Out:
# === VÉRIFICATION DES TAILLES ===
# Taille de X  : (10, 8)
# Taille de S : (10, 10)
# Taille de A   : (10, 10)
# Taille de O   : (10, 8)
#
# === CONTENU DE LA MATRICE A (Ligne 3) ===
# [2.05594208e-04 5.32703791e-03 7.83077712e-05 9.86777033e-01
#  7.30010821e-04 5.59170267e-03 7.75525953e-06 5.60829066e-06
#  1.83079994e-05 1.25864177e-03]
# Somme de la ligne 3 : 1.0
#
# === COMPARAISON X vs O (Ligne 0) ===
# Vecteur original X[0] du mot they :
# [-1.37221402 -0.16554685  0.01326373 -0.32740613 -0.15222046 -0.59905108
#  -0.0346078  -0.25655423]
# Vecteur mis à jour O[0] du mot they:
# [-1.11289972  0.02049149 -0.20395345  0.11896652 -0.01026596 -0.58315356
#   0.25953054 -0.62059584]
